# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
new =pd.read_csv(r"C:\Users\Suhas\Downloads\SME Stores Data.csv\SME Stores Data.csv")
new
# Out:
# C:\Users\Suhas\AppData\Local\Temp\ipykernel_17180\3639603214.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   new =pd.read_csv(r"C:\Users\Suhas\Downloads\SME Stores Data.csv\SME Stores Data.csv")
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  31-07-2022   5263        555     1      1
# 1            2          5  31-07-2022   6064        625     1      1
# 2            3          5  31-07-2022   8314        821     1      1
# 3            4          5  31-07-2022  13995       1498     1      1
# 4            5          5  31-07-2022   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  01-01-2020      0          0     0      0
# 1017205   1112          2  01-01-2020      0          0     0      0
# 1017206   1113          2  01-01-2020      0          0     0      0
# ...

# %%
new.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  31-07-2022   5263        555     1      1            0
# 1      2          5  31-07-2022   6064        625     1      1            0
# 2      3          5  31-07-2022   8314        821     1      1            0
# 3      4          5  31-07-2022  13995       1498     1      1            0
# 4      5          5  31-07-2022   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
new.tail()
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1017204   1111          2  01-01-2020      0          0     0      0
# 1017205   1112          2  01-01-2020      0          0     0      0
# 1017206   1113          2  01-01-2020      0          0     0      0
# 1017207   1114          2  01-01-2020      0          0     0      0
# 1017208   1115          2  01-01-2020      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1

# %%
new.shape
# Out:
# (1017209, 9)

# %%
new.isnull()
# Out:
#          Store  DayOfWeek   Date  Sales  Customers   Open  Promo  \
# 0        False      False  False  False      False  False  False
# 1        False      False  False  False      False  False  False
# 2        False      False  False  False      False  False  False
# 3        False      False  False  False      False  False  False
# 4        False      False  False  False      False  False  False
# ...        ...        ...    ...    ...        ...    ...    ...
# 1017204  False      False  False  False      False  False  False
# 1017205  False      False  False  False      False  False  False
# 1017206  False      False  False  False      False  False  False
# 1017207  False      False  False  False      False  False  False
# 1017208  False      False  False  False      False  False  False
#
#          StateHoliday  SchoolHoliday
# 0               False          False
# 1               False          False
# 2               False          False
# ...

# %%
new.isnull().count()
# Out:
# Store            1017209
# DayOfWeek        1017209
# Date             1017209
# Sales            1017209
# Customers        1017209
# Open             1017209
# Promo            1017209
# StateHoliday     1017209
# SchoolHoliday    1017209
# dtype: int64

# %%
#Exploratory Data Analysis
# y= b0+b1x1+b2x2+b3x3+e
x= new[['Store','DayOfWeek','Customers']]
y = new['Sales']
x1 = new['Store']
x2 =new['DayOfWeek']
x3 =new['Customers']

# %%
#b0,b1,b2,b3,e

# %%
#traini + testing split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
#         Store  DayOfWeek  Customers
# 635787   1023          1        648
# 621011    742          7          0
# 69929     800          6        476
# 53248     844          7          0
# 658989    810          1        557
# ...       ...        ...        ...
# 963395    821          1       1082
# 117952    878          5        842
# 435829    650          5        755
# 305711    176          6        355
# 985772    898          2        689
#
# [813767 rows x 3 columns]

# %%
y_train
# Out:
# 635787     6394
# 621011        0
# 69929      5369
# 53248         0
# 658989     7288
#           ...
# 963395    10208
# 117952    10492
# 435829     7404
# 305711     2864
# 985772     5541
# Name: Sales, Length: 813767, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#beta 1
model.coef_
# Out:
# array([-1.82488723e-01, -2.64177861e+02,  6.97836721e+00])

# %%
#beta 0
model.intercept_
# Out:
# np.float64(2512.496266684885)

# %%
y=2512.4962666850465 + -1.82488723e-01*x1 +-2.64177861e+02*x2 + 6.97836721e+00*x3
(y)
# Out:
# 0           5064.418275
# 1           5552.721490
# 2           6920.298975
# 3          11644.471087
# 4           5091.601788
#                ...
# 1017204     1781.395573
# 1017205     1781.213085
# 1017206     1781.030596
# 1017207     1780.848107
# 1017208     1780.665619
# Length: 1017209, dtype: float64

# %%
ypred=2512.4962666850465 + -1.82488723e-01*1023 +-2.64177861e+02*1 + 6.97836721e+00*648
(y)
# Out:
# 0           5064.418275
# 1           5552.721490
# 2           6920.298975
# 3          11644.471087
# 4           5091.601788
#                ...
# 1017204     1781.395573
# 1017205     1781.213085
# 1017206     1781.030596
# 1017207     1780.848107
# 1017208     1780.665619
# Length: 1017209, dtype: float64

# %%
ypred
# Out:
# 6583.614394136046

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 1161.0675102957632
# Mean Squared Error: 2707715.230792714
# R-squared: 0.8167595029661219

# %%
new_data = np.array([[1023,1, 648]])
new_prediction = model.predict(new_data)
# Out:
# d:\ml.model\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
new_prediction
# Out:
# array([6583.61439121])

# %%
new = pd.DataFrame({'Actual':y_test, 'predicted':y_pred})
new
# Out:
#         Actual     predicted
# 982497    7285   7679.298560
# 719065    6221  12503.788250
# 145542    8132   9865.155090
# 252177   20916   9993.437317
# 479489    5472   6326.655736
# ...        ...           ...
# 181840    5650   5966.226129
# 349515    5464   6162.999919
# 710927    6191   6674.815073
# 971200    5663   7569.535053
# 14246     2698   2361.279194
#
# [203442 rows x 2 columns]

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")

# You can also add a reference line for a perfect match (y = x)
min_val = min(np.min(y_test), np.min(y_pred))
max_val = max(np.max(y_test), np.max(y_pred))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')

plt.show()

# %%
from scipy import stats
r = stats.linregress(y_test, y_pred)
print("R-squared value", r)
# Out:
# R-squared value LinregressResult(slope=np.float64(0.8155486623973901), intercept=np.float64(1059.985921522417), rvalue=np.float64(0.9037497761652918), pvalue=np.float64(0.0), stderr=np.float64(0.0008564249483499522), intercept_stderr=np.float64(5.943945910753737))

# %%
import pickle

# %%
with open("linear.pkl","wb") as file:
    pickle.dump(model,file)
